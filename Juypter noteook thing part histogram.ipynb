# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# pull 1000 random numbers Poisson distribution
samples = np.random.poisson(lam=5, size=1000)

# %%
plt.hist(samples, bins=100)
plt.xlabel("value")
plt.ylabel("count")

plt.savefig("histogram.pdf")
plt.show()
